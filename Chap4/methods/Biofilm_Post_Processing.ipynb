# %% [markdown]
# # Post processing of the biofilm simulations

# %% [markdown]
# This notebook processes the data for the biofilm simulations. We are looking at the distributions of particulate species along the height of the biofilm domain.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from src.post_process import load_result
from src.post_process import plot_subplot

# %% [markdown]
# ## Loading in the data
#
# Here we will load in the data for each timestep. The data are located in the `./data/` directory, and contain the results for the different cases. We want the time steps appended with 4 (1 day), 16 (4 days), 28 (7 days) and 40 (10 days). We have 5 cases to analyse.

# %%
#Case 1
case1_day01 = load_result("./data/case1/appGrowth.4.csv")
case1_day04 = load_result("./data/case1/appGrowth.16.csv")
case1_day07 = load_result("./data/case1/appGrowth.28.csv")
case1_day10 = load_result("./data/case1/appGrowth.40.csv")

# %%
#Case 2
case2_day01 = load_result("./data/case2/appGrowth.4.csv")
case2_day04 = load_result("./data/case2/appGrowth.16.csv")
case2_day07 = load_result("./data/case2/appGrowth.28.csv")
case2_day10 = load_result("./data/case2/appGrowth.40.csv")

# %%
#Case 3
case3_day01 = load_result("./data/case3/appGrowth.5.csv")
case3_day04 = load_result("./data/case3/appGrowth.16.csv")
case3_day07 = load_result("./data/case3/appGrowth.28.csv")
case3_day10 = load_result("./data/case3/appGrowth.40.csv")

# %%
# Case 4
case4_day01 = load_result("./data/case4/appGrowth.4.csv")
case4_day04 = load_result("./data/case4/appGrowth.16.csv")
case4_day07 = load_result("./data/case4/appGrowth.28.csv")
case4_day10 = load_result("./data/case4/appGrowth.40.csv")

# %%
# Case 5
case5_day01 = load_result("./data/case5/appGrowth.4.csv")
case5_day04 = load_result("./data/case5/appGrowth.16.csv")
case5_day07 = load_result("./data/case5/appGrowth.28.csv")
case5_day10 = load_result("./data/case5/appGrowth.40.csv")

# %%
# Case 6
case6_day01 = load_result("./data/case6/appGrowth.4.csv")
case6_day04 = load_result("./data/case6/appGrowth.17.csv")
case6_day07 = load_result("./data/case6/appGrowth.28.csv")
case6_day10 = load_result("./data/case6/appGrowth.40.csv")

# %% [markdown]
# ## Plotting the data
#
# The plotting utility has been wrapped up in the `./src/` directory. It is basically just a series of matplotlib pyplot commands that have some custom calls. This first series of plots has the volume fractions of XPB, XS and XI as well as the complementary volume fraction of the bulk liquid.

# %%
# Case 1
plot_subplot(case1_day01, case1_day04, case1_day07, case1_day10)
plt.savefig("./output/case1.png")

# %%
# Case 2
plot_subplot(case2_day01, case2_day04, case2_day07, case2_day10)
plt.savefig("./output/case2.png")

# %%
# Case 3
plot_subplot(case3_day01, case3_day04, case3_day07, case3_day10)
plt.savefig("./output/case3.png")

# %%
# Case 4
plot_subplot(case4_day01, case4_day04, case4_day07, case4_day10)
plt.savefig("./output/case4.png")

# %%
# Case 5
plot_subplot(case5_day01, case5_day04, case5_day07, case5_day10)
plt.savefig("./output/case5.png")

# %%
# Case 6
plot_subplot(case6_day01, case6_day04, case6_day07, case6_day10)
plt.savefig("./output/case6.png")
